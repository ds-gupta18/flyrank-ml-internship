# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ds-gupta18/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Ranking Signal Analysis
#
# I chose the Ranking Signal Analysis lane because it focuses on identifying pages that are likely losing search performance using measurable ranking signals. Instead of updating every page, this approach helps prioritize pages that deserve attention first. I want to learn how simple, explainable machine learning can help rank pages for review based on signals such as impressions, CTR, average position, and content freshness.

# %%
# Lane selected
lane = "Ranking Signal Analysis"
print("Selected Lane:", lane)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should be reviewed first because they are likely declining in search performance?
#
# Action: The SEO or content team will review the highest-ranked pages, update their content if needed, and improve their search visibility.
#
# Cost of a wrong call: If we recommend the wrong pages, the team wastes time reviewing pages that do not need updates while truly declining pages continue losing traffic and rankings.

# %%
decision = "Review declining pages first"
print("Decision:", decision)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# From the starter dataset, there are 30,000 pages available for analysis. Around 54.2% of the pages are labeled as declining (declining rate = 0.542). These numbers show that a large portion of pages may require review, making it important to rank pages so the content team can focus on the highest-priority ones first.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Declining rate:", round(df["is_declining_label"].mean(), 3))
print(df[["impressions_90d","avg_position","ctr"]].describe())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision support, not certainty. It can identify patterns and rank pages that appear more likely to need review based on the available data. It does not prove why a page declined, guarantee future rankings, or predict Google's algorithm. Final decisions should always be made by the content team after reviewing the recommended pages.

# %%
print("This notebook provides decision support, not proof.")

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
